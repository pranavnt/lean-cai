# %%
import os
os.environ["GITHUB_ACCESS_TOKEN"]="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"

#GITHUB_ACCESS_TOKEN="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"

# %%
from lean_dojo import LeanGitRepo, Theorem, get_traced_repo_path, trace, TracedRepo
# Out:
# 2024-05-20 12:20:46,231	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
mil_textbook = {
  'url': 'https://github.com/leanprover-community/mathematics_in_lean',
  'commit': 'df46ab9048edb89df1491db0e4db16155c4c735f'
}

# %%
mil_repo = LeanGitRepo(mil_textbook['url'], mil_textbook['commit'])

# %%
traced_mil_repo = trace(mil_repo)
# Out:
# 2024-05-20 12:44:21.651 | INFO     | lean_dojo.data_extraction.trace:get_traced_repo_path:79 - Tracing LeanGitRepo(url='https://github.com/leanprover-community/mathematics_in_lean', commit='df46ab9048edb89df1491db0e4db16155c4c735f')
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %%
traced_mil_repo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/pranavnt/src/pranavnt/lean-cai/lean_cai/explore.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/pranavnt/src/pranavnt/lean-cai/lean_cai/explore.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> traced_mil_repo
#
# NameError: name 'traced_mil_repo' is not defined

# %%
repo_info = {
    'url': 'https://github.com/leanprover-community/mathlib4',
    'commit': 'fe4454af900584467d21f4fd4fe951d29d9332a7',
}

# %%
repo = LeanGitRepo(repo_info['url'], repo_info['commit'])

# %%
local_dir = './data'

traced_repo_path = get_traced_repo_path(repo)

# %%
if traced_repo_path is None:
    traced_repo = trace(repo, dst_dir=local_dir)
else:
    traced_repo = TracedRepo.load_from_disk(traced_repo_path)
# Out:
# 2024-05-19 04:43:12,680	INFO worker.py:1740 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 100%|██████████| 5192/5192 [06:00<00:00, 14.41it/s]
# Following Github server redirection from /repos/leanprover/std4 to /repositories/529900532
# 2024-05-19 04:49:49.372 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/leanprover/lean4-cli', commit='be8fa79a28b8b6897dce0713ef50e89c4a0f6ef5') relies on an unsupported Lean version: ec941735c80dc54c53948e30c428905b6600f95a
# Following Github server redirection from /repos/mhuisi/lean4-cli to /repositories/341363356
# 2024-05-19 04:50:27.554 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/mhuisi/lean4-cli', commit='10d88b52fa8d717fa8e29af3abf0c3a2bf175497') relies on an unsupported Lean version: 41697dcf6cab7ec82723ba404f2bda7a4526bb2b
# ...

# %%
theorems = [thrm.theorem for thrm in traced_repo.get_traced_theorems()]

# %%
for theorem in theorems:
    print(theorem)

    break
# Out:
# Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/ProofWidgets4', commit='fb65c476595a453a9b8ffc4a1cea2db3a89b9cd8'), file_path=PosixPath('ProofWidgets/Demos/Jsx.lean'), full_name='ghjk')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/pranavnt/src/pranavnt/lean-cai/lean_cai/explore.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/Users/pranavnt/src/pranavnt/lean-cai/lean_cai/explore.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> for theorem in theorems:
#       <a href='vscode-notebook-cell:/Users/pranavnt/src/pranavnt/lean-cai/lean_cai/explore.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>     print(theorem)
# ----> <a href='vscode-notebook-cell:/Users/pranavnt/src/pranavnt/lean-cai/lean_cai/explore.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>     print(traced_repo.get_traced_file(theorem.file_path))
# ...

# %%
traced_repo.get_traced_file("Mathlib/Analysis/NormedSpace/Star/ContinuousFunctionalCalculus/Instances.lean").get_traced_theorems()
# Out:
# [TracedTheorem(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/NormedSpace/Star/ContinuousFunctionalCalculus/Instances.lean'), full_name='isSelfAdjoint_iff_isStarNormal_and_spectrumRestricts')),
#  TracedTheorem(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/NormedSpace/Star/ContinuousFunctionalCalculus/Instances.lean'), full_name='IsSelfAdjoint.spectrumRestricts')),
#  TracedTheorem(theorem=Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='fe4454af900584467d21f4fd4fe951d29d9332a7'), file_path=PosixPath('Mathlib/Analysis/NormedSpace/Star/ContinuousFunctionalCalculus/Instances.lean'), full_name='SpectrumRestricts.isSelfAdjoint')),
# ...

# %%
import random

# Sample 10 nodes randomly from the traced files graph and print each
sampled_nodes = random.sample(list(traced_repo.traced_files_graph.nodes), 10)
for node in sampled_nodes:
    print(node)
# Out:
# Mathlib/CategoryTheory/Limits/Shapes/Types.lean
# .lake/packages/lean4/src/lean/Lean/Elab/Deriving/TypeName.lean
# Mathlib/Analysis/NormedSpace/Star/ContinuousFunctionalCalculus/Instances.lean
# Mathlib/Topology/Algebra/Module/Multilinear/Bounded.lean
# Mathlib/Analysis/BoxIntegral/Partition/Measure.lean
# Mathlib/Analysis/Calculus/TangentCone.lean
# Mathlib/CategoryTheory/Adjunction/Limits.lean
# Mathlib/Logic/Small/Defs.lean
# .lake/packages/lean4/src/lean/Lean/Server/References.lean
# Mathlib/Data/Finset/Finsupp.lean

# %%
theorems
# Out:
# [Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/ProofWidgets4', commit='fb65c476595a453a9b8ffc4a1cea2db3a89b9cd8'), file_path=PosixPath('ProofWidgets/Demos/Jsx.lean'), full_name='ghjk'),
#  Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/ProofWidgets4', commit='fb65c476595a453a9b8ffc4a1cea2db3a89b9cd8'), file_path=PosixPath('ProofWidgets/Demos/Venn.lean'), full_name='Set.ext'),
#  Theorem(repo=LeanGitRepo(url='https://github.com/leanprover/std4', commit='ff9850c4726f6b9fb8d8e96980c3fcb2900be8bd'), file_path=PosixPath('Std/Logic.lean'), full_name='heq_iff_eq'),
#  Theorem(repo=LeanGitRepo(url='https://github.com/leanprover/std4', commit='ff9850c4726f6b9fb8d8e96980c3fcb2900be8bd'), file_path=PosixPath('Std/Logic.lean'), full_name='proof_irrel_heq'),
#  Theorem(repo=LeanGitRepo(url='https://github.com/leanprover/std4', commit='ff9850c4726f6b9fb8d8e96980c3fcb2900be8bd'), file_path=PosixPath('Std/Logic.lean'), full_name='eq_rec_constant'),
# ...

# %%
from typing import List
import tqdm

class LeanTheorem:
    name: str
    statement: str
    proof: str
    imports: List[str]
    comments: List[str]

    def __init__(self, name: str, statement: str, proof: str, imports: List[str], comments: List[str]):
        self.name = name
        self.statement = statement
        self.proof = proof
        self.imports = imports
        self.comments = comments

theorems = []
num_none = 0

for traced_file in traced_repo.traced_files:
    for traced_theorem in traced_file.get_traced_theorems():
        name = traced_theorem.theorem.full_name
        statement = traced_theorem.get_theorem_statement()
        proof = traced_theorem.get_tactic_proof()
        imports = traced_file.get_direct_dependencies(traced_repo.repo)
        comments = [str(comment) for comment in traced_theorem.comments]
        theorem = LeanTheorem(name, statement, proof, imports, comments)

        # print(theorem.name)
        # print(theorem.statement)
        # print(theorem.proof)
        # print(theorem.imports)
        # print(theorem.comments)
        if proof is None:
            num_none += 1


        theorems.append(theorem)
        if (len(theorems)) % 100 == 0:
            print(str(len(theorems)) + " " + str(num_none))
# Out:
# 100 67
# 200 106
# 300 163
# 400 218
# 500 247
# 600 298
# 700 344
# 800 384
# 900 430
# 1000 508
# 1100 571
# 1200 653
# 1300 710
# 1400 766
# 1500 808
# 1600 856
# 1700 917
# 1800 990
# 1900 1031
# 2000 1073
# 2100 1142
# 2200 1196
# 2300 1290
# 2400 1364
# 2500 1420
# 2600 1464
# 2700 1484
# 2800 1577
# 2900 1641
# 3000 1703
# 3100 1757
# 3200 1769
# 3300 1809
# 3400 1845
# 3500 1909
# 3600 1978
# 3700 2022
# 3800 2070
# 3900 2156
# 4000 2214
# 4100 2257
# 4200 2289
# 4300 2370
# 4400 2446
# 4500 2508
# 4600 2552
# 4700 2611
# 4800 2657
# 4900 2693
# 5000 2766
# 5100 2827
# 5200 2888
# 5300 2927
# 5400 2995
# 5500 3062
# 5600 3132
# 5700 3194
# 5800 3264
# 5900 3348
# 6000 3417
# 6100 3450
# 6200 3534
# 6300 3601
# 6400 3687
# 6500 3781
# 6600 3854
# 6700 3926
# 6800 4003
# 6900 4089
# 7000 4170
# 7100 4252
# 7200 4324
# 7300 4415
# 7400 4507
# 7500 4594
# 7600 4664
# 7700 4746
# 7800 4814
# 7900 4903
# 8000 4983
# 8100 5044
# 8200 5133
# 8300 5222
# 8400 5299
# 8500 5362
# ...

# %%
import pickle
pickle.dump(theorems, open("theorems_f.pkl", "wb"))

# %%
theorems_with_proofs = [thrm for thrm in theorems if thrm.proof is not None]
pickle.dump(theorems_with_proofs, open("theorems_with_proofs.pkl", "wb"))

# %%
print(theorems_with_proofs[1020].name)
print(theorems_with_proofs[1020].statement)
print(theorems_with_proofs[1020].proof)
print(theorems_with_proofs[1020].comments)
print(theorems_with_proofs[1020].imports)
# Out:
# List.Pairwise.forall_of_forall_of_flip
# theorem Pairwise.forall_of_forall_of_flip (h₁ : ∀ x ∈ l, R x x) (h₂ : Pairwise R l)
#     (h₃ : l.Pairwise (flip R)) : ∀ ⦃x⦄, x ∈ l → ∀ ⦃y⦄, y ∈ l → R x y :=
# by
#   induction l with
#   | nil => exact forall_mem_nil _
#   | cons a l ih =>
#     rw [pairwise_cons] at h₂ h₃
#     simp only [mem_cons]
#     rintro x (rfl | hx) y (rfl | hy)
#     · exact h₁ _ (l.mem_cons_self _)
#     · exact h₂.1 _ hy
#     · exact h₃.1 _ hx
#     · exact ih (fun x hx => h₁ _ <| mem_cons_of_mem _ hx) h₂.2 h₃.2 hx hy
# []
# [('Std.Data.List.Count', PosixPath('.lake/packages/std/Std/Data/List/Count.lean')), ('Init', PosixPath('.lake/packages/lean4/src/lean/Init.lean')), ('Std.Data.Fin.Lemmas', PosixPath('.lake/packages/std/Std/Data/Fin/Lemmas.lean'))]

# %%
import pickle
qa_data = pickle.load(open("../data/qa_data.pkl", "rb"))

# %%
prev_data = pickle.load(open("../data/qa/old/qa_data_16000_.pkl", "rb"))

# %%
# merge qa_data nd prev_data
qa_data.extend(prev_data)

# %%
final_qa_data = pickle.load(open("../data/final_qa.pkl", "rb"))

# %%
import json
# JSONL_PATH = "../data/lean_mathlib_sft2.jsonl"


def convert_to_llama3_format(data):
    output = "<|begin_of_text|>"

    for message in data:
        role = message['role']
        content = message['content'].replace('\n', '\\n')

        output += f"<|start_header_id|>{role}<|end_header_id|>\n"
        output += f"{content}<|eot_id|>"

    output += "<|start_header_id|>assistant<|end_header_id|>\n<|end_of_text|>"

    return output

# # append each data point to a line in the jsonl path where each line is:
# # {"text": "conversation in llama3 format"}
# for conversation in final_qa_data:
#   with open(JSONL_PATH, 'a') as f:
#     f.write(json.dumps({"text": convert_to_llama2_format(conversation)}) + '\n')

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
model_path = "../llama3-mathlib-sft"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards: 100%|██████████| 4/4 [00:09<00:00,  2.35s/it]

# %%
def sample(model: AutoModelForCausalLM, tokenizer: AutoTokenizer, prompt: str, max_new_tokens: int = 400):
  messages_arr = [
    {"role": "system", "content": "You are a helpful assistant helping with mathematical formalization in Lean."},
    {"role": "user", "content": prompt}
  ]

  messages = "<|begin_of_text|>"

  for message in messages_arr:
    role = message['role']
    content = message['content'].replace('\n', '\\n')

    messages += f"<|start_header_id|>{role}<|end_header_id|>\n"
    messages += f"{content}<|eot_id|>"

    messages += "<|start_header_id|>assistant<|end_header_id|>\n"

  input_ids = tokenizer.encode(messages, return_tensors="pt")
  output = model.generate(input_ids, max_new_tokens=max_new_tokens)
  return tokenizer.decode(output[0])

print(sample(model, tokenizer, """Prove the following theorem:

theorem aime_1983_p1
  (x y z w : ℕ)
  (ht : 1 < x ∧ 1 < y ∧ 1 < z)
  (hw : 0 ≤ w)
  (h0 : real.log w / real.log x = 24)
  (h1 : real.log w / real.log y = 40)
  (h2 : real.log w / real.log (x * y * z) = 12):
  real.log w / real.log z = 60 :=
"""))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
# You are a helpful assistant helping with mathematical formalization in Lean.<|eot_id|><|start_header_id|>assistant<|end_header_id|>
# <|start_header_id|>user<|end_header_id|>
# Prove the following theorem:\n\ntheorem aime_1983_p1\n  (x y z w : ℕ)\n  (ht : 1 < x ∧ 1 < y ∧ 1 < z)\n  (hw : 0 ≤ w)\n  (h0 : real.log w / real.log x = 24)\n  (h1 : real.log w / real.log y = 40)\n  (h2 : real.log w / real.log (x * y * z) = 12):\n  real.log w / real.log z = 60 :=\n<|eot_id|><|start_header_id|>assistant<|end_header_id|>
# ...
